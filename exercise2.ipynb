# %%
import pyscipopt as scip
import numpy as np

# %%
model = scip.Model('Greatest Common Divisior')

# %%
a = int(np.random.rand() * 100)
b = int(np.random.rand() * 100)

# %%
x = model.addVar(vtype = 'I', lb=-1000 , name = 'x')
y = model.addVar(vtype = 'I', lb=-1000 , name = 'y')

# %%
constraint1 = model.addCons(a * x + b * y >= 1, name = 'x_pos')

# %%
model.setObjective(a * x + b * y)

# %%
model.optimize()
# Out:
# feasible solution found by trivial heuristic after 0.0 seconds, objective value 9.200000e+06
# presolving:
# (round 1, fast)       0 del vars, 0 del conss, 0 add conss, 2 chg bounds, 1 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       0 del vars, 0 del conss, 0 add conss, 4 chg bounds, 1 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, exhaustive) 0 del vars, 0 del conss, 0 add conss, 4 chg bounds, 1 chg sides, 0 chg coeffs, 1 upgd conss, 0 impls, 0 clqs
#    (0.0s) symmetry computation started: requiring (bin +, int +, cont +), (fixed: bin -, int -, cont -)
#    (0.0s) no symmetry present (symcode time: 0.00)
# presolving (4 rounds: 4 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 0 added constraints, 4 tightened bounds, 0 added holes, 1 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 2 variables (0 bin, 2 int, 0 impl, 0 cont) and 1 constraints
# ...

# %%
print(f"The model status is '{model.getStatus()}', solved after {model.getSolvingTime()} seconds.")
print(f"The gcd of {a} and {b} is {model.getObjVal()}.")
print(f"It can be represented as gcd({a}, {b}) = {model.getObjVal()} = {a} * {model.getVal(x)} + {b} * {model.getVal(y)}.")
# Out:
# The model status is 'optimal', solved after 0.007133 seconds.
# The gcd of 56 and 36 is 4.0.
# It can be represented as gcd(56, 36) = 4.0 = 56 * -178.0 + 36 * 277.0.

# %%
def EuclidAlgorithm(a,b,t = 1):
    if t == 1:
        a,b = max(a,b), min(a,b)

    if a == 0:
        return b
    if b == 0:
        return a
    
    return EuclidAlgorithm(b, a % b, 0)

# %%
EuclidAlgorithm(56,36)
# Out:
# 4
